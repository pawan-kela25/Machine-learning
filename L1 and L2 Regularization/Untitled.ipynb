# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
df = pd.read_csv('Melbourne_housing_FULL.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.drop(['Date','YearBuilt','Lattitude','Longtitude','Address','Postcode'],inplace=True,axis=1)
df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG  Distance  Bedroom2  \
# 0  Abbotsford      2    h        NaN     SS  Jellis       2.5       2.0
# 1  Abbotsford      2    h  1480000.0      S  Biggin       2.5       2.0
# 2  Abbotsford      2    h  1035000.0      S  Biggin       2.5       2.0
# 3  Abbotsford      3    u        NaN     VB  Rounds       2.5       3.0
# 4  Abbotsford      3    h  1465000.0     SP  Biggin       2.5       3.0
#
#    Bathroom  Car  Landsize  BuildingArea         CouncilArea  \
# 0       1.0  1.0     126.0           NaN  Yarra City Council
# 1       1.0  1.0     202.0           NaN  Yarra City Council
# 2       1.0  0.0     156.0          79.0  Yarra City Council
# 3       2.0  1.0       0.0           NaN  Yarra City Council
# 4       2.0  0.0     134.0         150.0  Yarra City Council
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# 2  Northern Metropolitan         4019.0
# ...

# %%
df.shape
# Out:
# (34857, 15)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.dropna(subset = ['CouncilArea','Regionname','Propertycount'],axis=0,inplace=True)
df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG  Distance  Bedroom2  \
# 0  Abbotsford      2    h        NaN     SS  Jellis       2.5       2.0
# 1  Abbotsford      2    h  1480000.0      S  Biggin       2.5       2.0
# 2  Abbotsford      2    h  1035000.0      S  Biggin       2.5       2.0
# 3  Abbotsford      3    u        NaN     VB  Rounds       2.5       3.0
# 4  Abbotsford      3    h  1465000.0     SP  Biggin       2.5       3.0
#
#    Bathroom  Car  Landsize  BuildingArea         CouncilArea  \
# 0       1.0  1.0     126.0           NaN  Yarra City Council
# 1       1.0  1.0     202.0           NaN  Yarra City Council
# 2       1.0  0.0     156.0          79.0  Yarra City Council
# 3       2.0  1.0       0.0           NaN  Yarra City Council
# 4       2.0  0.0     134.0         150.0  Yarra City Council
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# 2  Northern Metropolitan         4019.0
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2          8214
# Bathroom          8223
# Car               8725
# Landsize         11807
# BuildingArea     21112
# CouncilArea          0
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
cols_to_fill = ['Bathroom','Landsize','Price']
df['Car'].fillna(0,inplace=True)
df['Bathroom'].fillna(0,inplace=True)
df['Landsize'].fillna(0,inplace=True)
df['Price'].fillna(df['Price'].mean(),inplace=True)
df['Bedroom2'].fillna(0,inplace=True)
df['BuildingArea'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.head()
# Out:
#        Suburb  Rooms Type         Price Method SellerG  Distance  Bedroom2  \
# 0  Abbotsford      2    h  1.050210e+06     SS  Jellis       2.5       2.0
# 1  Abbotsford      2    h  1.480000e+06      S  Biggin       2.5       2.0
# 2  Abbotsford      2    h  1.035000e+06      S  Biggin       2.5       2.0
# 3  Abbotsford      3    u  1.050210e+06     VB  Rounds       2.5       3.0
# 4  Abbotsford      3    h  1.465000e+06     SP  Biggin       2.5       3.0
#
#    Bathroom  Car  Landsize  BuildingArea         CouncilArea  \
# 0       1.0  1.0     126.0           0.0  Yarra City Council
# 1       1.0  1.0     202.0           0.0  Yarra City Council
# 2       1.0  0.0     156.0          79.0  Yarra City Council
# 3       2.0  1.0       0.0           0.0  Yarra City Council
# 4       2.0  0.0     134.0         150.0  Yarra City Council
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# ...

# %%
df.drop(['Suburb','Type',"Method",'SellerG','CouncilArea','Regionname'],axis=1,inplace=True)

# %%
# df1 = pd.get_dummies(df,drop_first=True)
# df1 = df1.replace({True:1,False:0})
# df = pd.concat([df,df1],axis=1)

# df.drop(['Suburb','Method','SellerG','CouncilArea','Regionname'],axis=1,inplace=True)
# df.drop('Type',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Rooms         Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2  1.050210e+06       2.5       2.0       1.0  1.0     126.0
# 1      2  1.480000e+06       2.5       2.0       1.0  1.0     202.0
# 2      2  1.035000e+06       2.5       2.0       1.0  0.0     156.0
# 3      3  1.050210e+06       2.5       3.0       2.0  1.0       0.0
# 4      3  1.465000e+06       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea  Propertycount
# 0           0.0         4019.0
# 1           0.0         4019.0
# 2          79.0         4019.0
# 3           0.0         4019.0
# 4         150.0         4019.0

# %%
X = df.drop('Price',axis=1)
y = df['Price']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)

print(f'train model score : {model.score(X_train,y_train)}')
print(f'test model score : {model.score(X_test,y_test)}')
# Out:
# train model score : 0.27732187838916367
# test model score : 0.27194000340508695
